# %% [markdown]
# <a href="https://colab.research.google.com/github/Dongdz2001/2D-plan-shooting/blob/main/yolowithcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alen-smajic/Real-time-Object-Detection-for-Autonomous-Driving-using-Deep-Learning.git
# Out:
# Cloning into 'Real-time-Object-Detection-for-Autonomous-Driving-using-Deep-Learning'...
# remote: Enumerating objects: 517, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 517 (delta 21), reused 5 (delta 2), pack-reused 477
# Receiving objects: 100% (517/517), 1.09 GiB | 17.18 MiB/s, done.
# Resolving deltas: 100% (237/237), done.
# Checking out files: 100% (47/47), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/19000413/bdd100k_labels_release.zip"
# Out:
# Archive:  /content/drive/MyDrive/19000413/bdd100k_labels_release.zip
# replace bdd100k/labels/bdd100k_labels_images_train.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: bdd100k/labels/bdd100k_labels_images_train.json  y
#
# replace bdd100k/labels/bdd100k_labels_images_val.json? [y]es, [n]o, [A]ll, [N]one, [r]ename:   inflating: bdd100k/labels/bdd100k_labels_images_val.json

# %%
# !unzip "/content/drive/MyDrive/19000413/bdd100k_images_100k.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: bdd100k/images/100k/val/c56ad92a-9e626450.jpg
#   inflating: bdd100k/images/100k/val/c3dc6d37-60d68540.jpg
#   inflating: bdd100k/images/100k/val/b5238f1c-f5d779fc.jpg
#   inflating: bdd100k/images/100k/val/b5e6efc0-ac69d492.jpg
#   inflating: bdd100k/images/100k/val/b5380a66-f8c670ed.jpg
#   inflating: bdd100k/images/100k/val/bc1fe060-06feda96.jpg
#   inflating: bdd100k/images/100k/val/b3467777-44b644dd.jpg
#   inflating: bdd100k/images/100k/val/c0e834fd-b666a542.jpg
#   inflating: bdd100k/images/100k/val/c5dd7a2a-bab83a60.jpg
#   inflating: bdd100k/images/100k/val/b9947c32-6074d84c.jpg
#   inflating: bdd100k/images/100k/val/b3048201-d86d9cd8.jpg
#   inflating: bdd100k/images/100k/val/b422ec08-236606a0.jpg
#   inflating: bdd100k/images/100k/val/b46efeed-a398b08d.jpg
#   inflating: bdd100k/images/100k/val/bffbaf67-67882851.jpg
#   inflating: bdd100k/images/100k/val/b398327e-3d2a2683.jpg
# ...

# %% [markdown]
# # New Section

# %%
# %cd "/content/Real-time-Object-Detection-for-Autonomous-Driving-using-Deep-Learning/YOLO/Training YOLO"
# !python3 train.py -tip bdd100k/images/100k/train/ -ttp bdd100k/labels/bdd100k_labels_images_train.json -lr 1e-5 -bs 10 -ne 100 -ls 1000 -nb 2 -lc 5 -ln 0.5 -lm 1 -lmf /content/drive/MyDrive/19000413/YOLO_bdd100k.pt
# Out:
# /content/Real-time-Object-Detection-for-Autonomous-Driving-using-Deep-Learning/YOLO/Training YOLO
# tcmalloc: large alloc 3288334336 bytes == 0x130e2000 @  0x7f1efb6e3b6b 0x7f1efb703379 0x7f1e8bca0d57 0x7f1e8bc8ebc3 0x7f1eb5b996af 0x7f1eb5b9a020 0x7f1eb5b9a074 0x7f1eb60abdef 0x7f1eb691db8b 0x7f1eb66691d3 0x7f1eb68f8b8f 0x7f1eb66a6bf7 0x7f1edd9a1585 0x512654 0x5b575e 0x4bad99 0x538786 0x5909f6 0x510946 0x5b575e 0x4bad99 0x538786 0x5909f6 0x510280 0x58fd37 0x50c4fc 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436
# ##################### LOADING YOLO MODEL ######################
#
# tcmalloc: large alloc 3288334336 bytes == 0x130e2000 @  0x7f1efb6e3b6b 0x7f1efb703379 0x7f1e8bca0d57 0x7f1e8bc8ebc3 0x7f1eb78711e0 0x7f1eddb48154 0x7f1edd7d1f61 0x58f6e4 0x590691 0x510946 0x5b575e 0x58ff2e 0x50c4fc 0x5b575e 0x4bad99 0x59178d 0x591ac9 0x5ef48d 0x4fef15 0x4d2197 0x51041f 0x5b575e 0x4bad0a 0x50e18c 0x5b4ee6 0x58ff2e 0x510325 0x58fd37 0x50c4fc 0x5b4ee6 0x6005a3
# ...

# %%
# %cd ..
# %cd /content/Real-time-Object-Detection-for-Autonomous-Driving-using-Deep-Learning/YOLO/Inference YOLO
# !python3 YOLO_to_image.py -w /content/drive/MyDrive/19000413/YOLO_bdd100k.pt -t 0.5 -ss 14 -nb 2 -nc 13 -i test.jpg -o out_put/output.png
# Out:
# /content/Real-time-Object-Detection-for-Autonomous-Driving-using-Deep-Learning/YOLO
# /content/Real-time-Object-Detection-for-Autonomous-Driving-using-Deep-Learning/YOLO/Inference YOLO
#
# ##### YOLO OBJECT DETECTION FOR IMAGES #####
#
# Loading the model
# ...
# tcmalloc: large alloc 3288334336 bytes == 0x145d0000 @  0x7f82cc305b6b 0x7f82cc325379 0x7f825c8c2d57 0x7f825c8b0bc3 0x7f82867bb6af 0x7f82867bc020 0x7f82867bc074 0x7f8286ccddef 0x7f828753fb8b 0x7f828728b1d3 0x7f828751ab8f 0x7f82872c8bf7 0x7f82ae5c3585 0x512654 0x5b575e 0x4bad99 0x538786 0x5909f6 0x510946 0x5b575e 0x4bad99 0x538786 0x5909f6 0x510280 0x58fd37 0x50c4fc 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436
# Amount of YOLO parameters: 900726108
# ...
# Loading model weights
# ...
# ...

# %%
# !python3 YOLO_to_video.py -w /content/drive/MyDrive/19000413/YOLO_bdd100k.pt -t 0.5 -ss 14 -nb 2 -nc 13 -i test.mp4 -o out_put/output.mp4
# Out:
# ##### YOLO OBJECT DETECTION FOR VIDEOS #####
#
# Loading the model
# ...
# tcmalloc: large alloc 3288334336 bytes == 0x133c0000 @  0x7f21e31d0b6b 0x7f21e31f0379 0x7f217378dd57 0x7f217377bbc3 0x7f219d6866af 0x7f219d687020 0x7f219d687074 0x7f219db98def 0x7f219e40ab8b 0x7f219e1561d3 0x7f219e3e5b8f 0x7f219e193bf7 0x7f21c548e585 0x512654 0x5b575e 0x4bad99 0x538786 0x5909f6 0x510946 0x5b575e 0x4bad99 0x538786 0x5909f6 0x510280 0x58fd37 0x50c4fc 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436
# Amount of YOLO parameters: 900726108
# ...
# Loading model weights
# ...
# tcmalloc: large alloc 3288334336 bytes == 0x133c0000 @  0x7f21e31d0b6b 0x7f21e31f0379 0x7f217378dd57 0x7f217377bbc3 0x7f219f35e1e0 0x7f21c5635154 0x7f21c52bef61 0x58f6e4 0x590691 0x510946 0x5b575e 0x58ff2e 0x50c4fc 0x5b575e 0x4bad99 0x59178d 0x591ac9 0x5ef48d 0x4fef15 0x4d2197 0x51041f 0x5b575e 0x4bad0a 0x50e18c 0x5b4ee6 0x58ff2e 0x510325 0x58fd37 0x50c4fc 0x5b4ee6 0x6005a3
# ...

# %%
# !cp -r "/content/yolovwitcnn" "/content/drive/MyDrive"
# Out:
# cp: cannot stat '/content/yolovwitcnn': No such file or directory
